# %%
from bs4 import BeautifulSoup
#Var.decode("utf-8")
with open("test.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    soup.decode('utf-8')

lines = soup.get_text().split('Von:')
for l in lines:
    print(l)
    print("ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ")
    print("ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ")
    print("ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ")
# Out:
# Bitte 2 Paar.
#
# Besten Dank
#
#
#
# Wachter
#
#
#
# Wachter & Wachter OG
#
#
#
# Widmanngasse 4- 9500 Villach
#
# office@uhren-schmuck-wachter.at
#
# ATU: 63531725 / FN:296980k
#
# TEL:+43 4242 29106 / FAX: +434242 29104
#
#
#
#
#
#
#
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
#  Verkauf (Paukner) [mailto:verkauf@palido.at]
#
# Gesendet: Donnerstag, 7. Mai 2020 09:00
# An: Wachter & Wachter
# Betreff: AW: HÃ¤nger / Collier
#
#
#
# Sehr geehrte Damen und Herren!
#
#
#
# Es gibt in Gelbgold folgenden Ohrschmuck:
#
#
#
# K10415/G
# VK: â‚¬ 139,-
#
# Bei Fragen stehen wir Ihnen gerne zur VerfÃ¼gung.
#
#
# Mit freundlichen GrÃ¼ÃŸen
# Petra Schlesinger
#
#
#
#
#
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
# ÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄÄ
#  Wachter & Wachter [mailto:office@uhren-schmuck-wachter.at]
#
# Gesendet: Mittwoch, 6. Mai 2020 16:40
# An: Verkauf (Paukner)
# Betreff: AW: HÃ¤nger / Collier
#
#
#
#
#
# Sehr geehrte Frau Novak.
#
#
# HÃ¤tten Sie dazu auch passende Ohrstecker?
#
#
#
# ...
